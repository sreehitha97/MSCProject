# %%
import pandas as pd
import networkx as nx
from collections import defaultdict
import pymfinder as py
import json
import math

# Load the transaction data
df = pd.read_csv('./Debit_Transactions1.csv')

# Extract relevant columns
df = df[['customerId', 'externalParty.merchantCategoryCode', 'createdAt', 'transactionFootPrint.carbonEmissionInGrams']]

# Convert 'createdAt' to datetime and sort by customer and timestamp
df['createdAt'] = pd.to_datetime(df['createdAt'])
df = df.sort_values(by=['customerId', 'createdAt'])

# Create transaction sequences by customer with carbon emissions
transaction_sequences = df.groupby('customerId').apply(
    lambda x: list(zip(x['externalParty.merchantCategoryCode'], x['transactionFootPrint.carbonEmissionInGrams']))
).reset_index(name='sequences')

# Initialize a directed graph
G = nx.DiGraph()

# Create dictionaries to store edge frequencies and carbon emissions
edge_freq = defaultdict(int)
edge_emissions = defaultdict(float)
node_emissions = defaultdict(list)  # Store all emissions for calculating average

# Add edges, their weights, and carbon emissions
for sequences in transaction_sequences['sequences']:
    for i in range(len(sequences)):
        node_id = sequences[i][0]
        emission = sequences[i][1]
        if pd.notna(emission):  # Check for NaN emissions
            node_emissions[node_id].append(emission)  # Collect emissions for average calculation
            if i < len(sequences) - 1:
                source = sequences[i][0]
                target = sequences[i + 1][0]
                edge_freq[(source, target)] += 1
                edge_emissions[(source, target)] += sequences[i + 1][1]

# Add edges to the graph with weights and emissions
for (source, target), weight in edge_freq.items():
    emission = edge_emissions.get((source, target), 0)
    G.add_edge(source, target, weight=weight, emissions=emission)

# Save the network to an edge list file (without emissions for pymfinder)
with open('network_edges.txt', 'w') as file:
    for edge in G.edges(data=True):
        source, target, data = edge
        weight = data['weight']
        file.write(f"{source} {target} {weight}\n")

# Function to convert NodeLink objects to a serializable format
def node_link_to_dict(node_link):
    return {
        "id": node_link.id,
        "motifs": node_link.motifs,
        "roles": node_link.roles,
        "weight": node_link.weight,
        "weighted_motifs": node_link.weighted_motifs,
        "weighted_roles": node_link.weighted_roles
    }

# Run pymfinder to detect motifs
results = py.pymfinder(
    network='network_edges.txt',
    links=True,
    motifsize=3,
    stoufferIDs=False,
    allmotifs=False,
    nrandomizations=0,
    randomize=False,
    usemetropolis=False,
    networktype="unipartite"
)

# Extract the data to save
results_dict = {
    "motifs": {motif_id: motif.real for motif_id, motif in results.motifs.items()},
    "nodes": {
        node_id: {
            "id": node.id,
            "motifs": node.motifs,
            "roles": node.roles,
            "weighted_motifs": node.weighted_motifs,
            "weighted_roles": node.weighted_roles
        } for node_id, node in results.nodes.items()
    },
    "links": [node_link_to_dict(link) for _, link in results.links.items()]  # Convert NodeLink to dict
}

# Function to convert tuple keys to strings
def convert_tuple_keys(d):
    if isinstance(d, dict):
        new_dict = {}
        for k, v in d.items():
            if isinstance(k, tuple):
                k = str(k)
            new_dict[k] = convert_tuple_keys(v)
        return new_dict
    elif isinstance(d, list):
        return [convert_tuple_keys(i) for i in d]
    else:
        return d

# Convert any tuple keys to strings
results_dict = convert_tuple_keys(results_dict)

# Save the results to a text file
with open('results.txt', 'w') as f:
    json.dump(results_dict, f, indent=4)

# Mapping of motifs to their initial nodes
initial_nodes = {
    (6, 0, 1),    # S1
    (12, 0, 1),   # S3
    (14, 0, 1),   # S7
    (36, 0, 2),   # S9
    (38, 0, 1),   # S11
    (46, 1, 1),   # S14 or S15 (both are initial and have the same structure)
    (74, 0, 1),   # S16
    (78, 0, 2),   # S19
    (98, 0, 2),   # S21
    (102, 0, 1),  # S23
    (108, 1, 1),  # S25 or S26 (both are initial and have the same structure)
    (238, 1, 1)   # S29 or S30 (both are initial and have the same structure)
}

# Convert initial_nodes to a set of motif IDs
initial_node_ids = {id for id, *_ in initial_nodes}


# Parsing results and calculating total emission per motif
def parse_results_from_file(file_path):
    with open(file_path, 'r') as f:
        results_dict = json.load(f)
    
    motifs = results_dict['motifs']
    nodes = results_dict['nodes']
    links = results_dict['links']
    
    return motifs, nodes, links

# %%
def calculate_total_emission_per_motif(motifs, nodes, links):
    motif_emissions = defaultdict(float)
    added_nodes = defaultdict(set)
    # Create a dictionary to map links to their motifs
    link_motifs = {tuple(link['id']): link['motifs'] for link in links}

    # Function to convert role string to a tuple
    def role_str_to_tuple(role_str):
        return tuple(map(int, role_str.strip('()').split(', ')))

    # Iterate through links to calculate emissions for each motif
    for link in links:
        edge_id = tuple(link['id'])
        associated_motifs = link['motifs']
        emission = G[edge_id[0]][edge_id[1]].get('emissions', 0)
        weight = G[edge_id[0]][edge_id[1]].get('weight', 1)

        for motif_id in associated_motifs:
            motif_id_int = int(motif_id)  # Ensure motif_id is an integer

            # Determine the multiplier based on the motif ID
            multiplier = 2 if motif_id_int in {36, 78} else 1

            if motif_id_int in initial_node_ids:
                # Convert node IDs to string format to access the nodes dictionary
                node_id_str_1 = edge_id[0]
                node_id_str_2 = edge_id[1]

                # Check if node_id_str_1 is in nodes by comparing `id`
                node_in_nodes = next((node for node in nodes.values() if node['id'] == int(node_id_str_1)), None)
                
                if node_in_nodes:
                    # Get roles with count > 0
                    node_roles = {role: count for role, count in node_in_nodes['roles'].items() if count > 0}
                   # print ("K")
                    # Convert roles to tuples for comparison
                    node_roles_tuples = {role_str_to_tuple(role) for role in node_roles}
                   # print (node_roles_tuples)
                    # Check if any role matches the initial node role for the motif
                    for role_tuple in node_roles_tuples:
                        #print (edge_id[0],role_tuple)
                        #print (initial_nodes)
                        if role_tuple in initial_nodes:
                            if not (edge_id[0] in added_nodes[motif_id_int]):
                                # Calculate initial emission
                                initial_emission = sum(node_emissions.get(edge_id[0], [])) / len(node_emissions[edge_id[0]])
                                initial_emission *= node_roles.get(str(role_tuple), 0)  # Multiply by count
                                initial_emission *= multiplier
                                print(f"Adding initial node emission:{edge_id[0]} {initial_emission} for motif {motif_id_int}")
                                motif_emissions[motif_id_int] += initial_emission
                                added_nodes[motif_id_int].add(edge_id[0])
                                print (added_nodes[motif_id_int])

            # Accumulate emission for the motif, but only if it's a valid number
            if not math.isnan(emission):
                motif_emissions[motif_id_int] += emission * (link['motifs'][motif_id] / weight)

    # Print total emissions for each motif
    print("Motif ID\tTotal Emission")
    for motif_id, total_emission in motif_emissions.items():
        print(f"{motif_id}\t{total_emission:.4f}")

# Run the function with the path to the results file
motifs, nodes, links = parse_results_from_file('results.txt')
calculate_total_emission_per_motif(motifs, nodes, links)
# Out:
# Adding initial node emission:5399 147217.8925 for motif 98
# {5399}
# Adding initial node emission:5399 294435.785 for motif 36
# {5399}
# Adding initial node emission:5399 147217.8925 for motif 38
# {5399}
# Adding initial node emission:5399 147217.8925 for motif 6
# {5399}
# Adding initial node emission:5399 147217.8925 for motif 102
# {5399}
# Adding initial node emission:5399 147217.8925 for motif 74
# {5399}
# Adding initial node emission:5399 147217.8925 for motif 12
# {5399}
# Adding initial node emission:5399 147217.8925 for motif 108
# {5399}
# Adding initial node emission:5399 147217.8925 for motif 14
# {5399}
# Adding initial node emission:5399 147217.8925 for motif 46
# {5399}
# Adding initial node emission:5399 294435.785 for motif 78
# {5399}
# Adding initial node emission:5399 147217.8925 for motif 238
# {5399}
# Adding initial node emission:4111 13594.85212121212 for motif 14
# {4111, 5399}
# Adding initial node emission:4111 13594.85212121212 for motif 46
# {4111, 5399}
# Adding initial node emission:4111 13594.85212121212 for motif 74
# {4111, 5399}
# Adding initial node emission:4111 27189.70424242424 for motif 78
# {4111, 5399}
# Adding initial node emission:4111 13594.85212121212 for motif 102
# {4111, 5399}
# Adding initial node emission:4111 13594.85212121212 for motif 238
# {4111, 5399}
# Adding initial node emission:4111 13594.85212121212 for motif 98
# {4111, 5399}
# Adding initial node emission:4111 27189.70424242424 for motif 36
# {4111, 5399}
# Adding initial node emission:4111 13594.85212121212 for motif 38
# {4111, 5399}
# Adding initial node emission:4111 13594.85212121212 for motif 6
# {4111, 5399}
# Adding initial node emission:4111 13594.85212121212 for motif 12
# {4111, 5399}
# Adding initial node emission:4111 13594.85212121212 for motif 108
# {4111, 5399}
# Adding initial node emission:5812 51079.95489130434 for motif 6
# {5812, 4111, 5399}
# Adding initial node emission:5812 51079.95489130434 for motif 12
# {5812, 4111, 5399}
# Adding initial node emission:5812 51079.95489130434 for motif 14
# {5812, 4111, 5399}
# Adding initial node emission:5812 51079.95489130434 for motif 46
# {5812, 4111, 5399}
# Adding initial node emission:5812 51079.95489130434 for motif 102
# {5812, 4111, 5399}
# Adding initial node emission:5812 51079.95489130434 for motif 98
# {5812, 4111, 5399}
# Adding initial node emission:5812 102159.90978260868 for motif 36
# {5812, 4111, 5399}
# Adding initial node emission:5812 51079.95489130434 for motif 38
# {5812, 4111, 5399}
# Adding initial node emission:5812 51079.95489130434 for motif 74
# {5812, 4111, 5399}
# Adding initial node emission:5812 51079.95489130434 for motif 108
# {5812, 4111, 5399}
# Adding initial node emission:5812 102159.90978260868 for motif 78
# {5812, 4111, 5399}
# Adding initial node emission:5812 51079.95489130434 for motif 238
# {5812, 4111, 5399}
# Adding initial node emission:5261 52115.115 for motif 14
# {5812, 4111, 5261, 5399}
# Adding initial node emission:5261 52115.115 for motif 74
# {5812, 4111, 5261, 5399}
# Adding initial node emission:5261 52115.115 for motif 102
# {5812, 4111, 5261, 5399}
# Adding initial node emission:5261 52115.115 for motif 108
# {5812, 4111, 5261, 5399}
# Adding initial node emission:5261 52115.115 for motif 98
# {5812, 4111, 5261, 5399}
# Adding initial node emission:5261 104230.23 for motif 36
# {5812, 4111, 5261, 5399}
# Adding initial node emission:5261 52115.115 for motif 38
# {5812, 4111, 5261, 5399}
# Adding initial node emission:5261 52115.115 for motif 6
# {5812, 4111, 5261, 5399}
# Adding initial node emission:5261 52115.115 for motif 12
# {5812, 4111, 5261, 5399}
# Adding initial node emission:5261 52115.115 for motif 46
# {5812, 4111, 5261, 5399}
# Adding initial node emission:5261 104230.23 for motif 78
# {5812, 4111, 5261, 5399}
# Adding initial node emission:5261 52115.115 for motif 238
# {5812, 4111, 5261, 5399}
# Adding initial node emission:5422 41067.135 for motif 12
# {5261, 5422, 4111, 5812, 5399}
# Adding initial node emission:5422 41067.135 for motif 14
# {5261, 5422, 4111, 5812, 5399}
# Adding initial node emission:5422 82134.27 for motif 36
# {5261, 5422, 4111, 5812, 5399}
# Adding initial node emission:5422 41067.135 for motif 102
# {5261, 5422, 4111, 5812, 5399}
# Adding initial node emission:5422 41067.135 for motif 108
# {5261, 5422, 4111, 5812, 5399}
# Adding initial node emission:5422 41067.135 for motif 98
# {5261, 5422, 4111, 5812, 5399}
# Adding initial node emission:5422 41067.135 for motif 38
# {5261, 5422, 4111, 5812, 5399}
# Adding initial node emission:5422 41067.135 for motif 6
# {5261, 5422, 4111, 5812, 5399}
# Adding initial node emission:5422 41067.135 for motif 74
# {5261, 5422, 4111, 5812, 5399}
# Adding initial node emission:5422 41067.135 for motif 46
# {5261, 5422, 4111, 5812, 5399}
# Adding initial node emission:5422 82134.27 for motif 78
# {5261, 5422, 4111, 5812, 5399}
# Adding initial node emission:5422 41067.135 for motif 238
# {5261, 5422, 4111, 5812, 5399}
# Adding initial node emission:5462 19965.960000000003 for motif 6
# {5261, 5422, 4111, 5812, 5462, 5399}
# Adding initial node emission:5462 19965.960000000003 for motif 12
# {5261, 5422, 4111, 5812, 5462, 5399}
# Adding initial node emission:5462 39931.920000000006 for motif 36
# {5261, 5422, 4111, 5812, 5462, 5399}
# Adding initial node emission:5462 19965.960000000003 for motif 98
# {5261, 5422, 4111, 5812, 5462, 5399}
# Adding initial node emission:5462 19965.960000000003 for motif 38
# {5261, 5422, 4111, 5812, 5462, 5399}
# Adding initial node emission:5462 19965.960000000003 for motif 102
# {5261, 5422, 4111, 5812, 5462, 5399}
# Adding initial node emission:5462 19965.960000000003 for motif 74
# {5261, 5422, 4111, 5812, 5462, 5399}
# Adding initial node emission:5462 19965.960000000003 for motif 108
# {5261, 5422, 4111, 5812, 5462, 5399}
# Adding initial node emission:5462 19965.960000000003 for motif 14
# {5261, 5422, 4111, 5812, 5462, 5399}
# Adding initial node emission:5462 19965.960000000003 for motif 46
# {5261, 5422, 4111, 5812, 5462, 5399}
# Adding initial node emission:5462 39931.920000000006 for motif 78
# {5261, 5422, 4111, 5812, 5462, 5399}
# Adding initial node emission:5462 19965.960000000003 for motif 238
# {5261, 5422, 4111, 5812, 5462, 5399}
# Adding initial node emission:5813 126055.05 for motif 98
# {5261, 5422, 4111, 5812, 5813, 5462, 5399}
# Adding initial node emission:5813 252110.1 for motif 36
# {5261, 5422, 4111, 5812, 5813, 5462, 5399}
# Adding initial node emission:5813 126055.05 for motif 38
# {5261, 5422, 4111, 5812, 5813, 5462, 5399}
# Adding initial node emission:5813 126055.05 for motif 6
# {5261, 5422, 4111, 5812, 5813, 5462, 5399}
# Adding initial node emission:5813 126055.05 for motif 102
# {5261, 5422, 4111, 5812, 5813, 5462, 5399}
# Adding initial node emission:5813 126055.05 for motif 74
# {5261, 5422, 4111, 5812, 5813, 5462, 5399}
# Adding initial node emission:5813 126055.05 for motif 12
# {5261, 5422, 4111, 5812, 5813, 5462, 5399}
# Adding initial node emission:5813 126055.05 for motif 108
# {5261, 5422, 4111, 5812, 5813, 5462, 5399}
# Adding initial node emission:5813 126055.05 for motif 14
# {5261, 5422, 4111, 5812, 5813, 5462, 5399}
# Adding initial node emission:5813 126055.05 for motif 46
# {5261, 5422, 4111, 5812, 5813, 5462, 5399}
# Adding initial node emission:5813 252110.1 for motif 78
# {5261, 5422, 4111, 5812, 5813, 5462, 5399}
# Adding initial node emission:5813 126055.05 for motif 238
# {5261, 5422, 4111, 5812, 5813, 5462, 5399}
# Adding initial node emission:7523 4276.83 for motif 14
# {7523, 5261, 5422, 4111, 5812, 5813, 5462, 5399}
# Adding initial node emission:7523 4276.83 for motif 74
# {7523, 5261, 5422, 4111, 5812, 5813, 5462, 5399}
# Adding initial node emission:7523 8553.66 for motif 78
# {7523, 5261, 5422, 4111, 5812, 5813, 5462, 5399}
# Adding initial node emission:7523 4276.83 for motif 102
# {7523, 5261, 5422, 4111, 5812, 5813, 5462, 5399}
# Adding initial node emission:7523 4276.83 for motif 238
# {7523, 5261, 5422, 4111, 5812, 5813, 5462, 5399}
# Adding initial node emission:7523 4276.83 for motif 98
# {7523, 5261, 5422, 4111, 5812, 5813, 5462, 5399}
# Adding initial node emission:7523 8553.66 for motif 36
# {7523, 5261, 5422, 4111, 5812, 5813, 5462, 5399}
# Adding initial node emission:7523 4276.83 for motif 38
# {7523, 5261, 5422, 4111, 5812, 5813, 5462, 5399}
# Adding initial node emission:7523 4276.83 for motif 6
# {7523, 5261, 5422, 4111, 5812, 5813, 5462, 5399}
# Adding initial node emission:7523 4276.83 for motif 12
# {7523, 5261, 5422, 4111, 5812, 5813, 5462, 5399}
# Adding initial node emission:7523 4276.83 for motif 108
# {7523, 5261, 5422, 4111, 5812, 5813, 5462, 5399}
# Adding initial node emission:7523 4276.83 for motif 46
# {7523, 5261, 5422, 4111, 5812, 5813, 5462, 5399}
# Adding initial node emission:5499 33824.784999999996 for motif 6
# {7523, 5261, 5422, 4111, 5812, 5813, 5462, 5399, 5499}
# Adding initial node emission:5499 33824.784999999996 for motif 12
# {7523, 5261, 5422, 4111, 5812, 5813, 5462, 5399, 5499}
# Adding initial node emission:5499 33824.784999999996 for motif 102
# {7523, 5261, 5422, 4111, 5812, 5813, 5462, 5399, 5499}
# Adding initial node emission:5499 33824.784999999996 for motif 98
# {7523, 5261, 5422, 4111, 5812, 5813, 5462, 5399, 5499}
# Adding initial node emission:5499 67649.56999999999 for motif 36
# {7523, 5261, 5422, 4111, 5812, 5813, 5462, 5399, 5499}
# Adding initial node emission:5499 33824.784999999996 for motif 38
# {7523, 5261, 5422, 4111, 5812, 5813, 5462, 5399, 5499}
# Adding initial node emission:5499 33824.784999999996 for motif 74
# {7523, 5261, 5422, 4111, 5812, 5813, 5462, 5399, 5499}
# Adding initial node emission:5499 33824.784999999996 for motif 108
# {7523, 5261, 5422, 4111, 5812, 5813, 5462, 5399, 5499}
# Adding initial node emission:5499 33824.784999999996 for motif 14
# {7523, 5261, 5422, 4111, 5812, 5813, 5462, 5399, 5499}
# Adding initial node emission:5499 33824.784999999996 for motif 46
# {7523, 5261, 5422, 4111, 5812, 5813, 5462, 5399, 5499}
# Adding initial node emission:5499 67649.56999999999 for motif 78
# {7523, 5261, 5422, 4111, 5812, 5813, 5462, 5399, 5499}
# Adding initial node emission:5499 33824.784999999996 for motif 238
# {7523, 5261, 5422, 4111, 5812, 5813, 5462, 5399, 5499}
# Adding initial node emission:5541 185288.98 for motif 12
# {7523, 5541, 5261, 5422, 4111, 5812, 5813, 5462, 5399, 5499}
# Adding initial node emission:5541 370577.96 for motif 36
# {7523, 5541, 5261, 5422, 4111, 5812, 5813, 5462, 5399, 5499}
# Adding initial node emission:5541 185288.98 for motif 74
# {7523, 5541, 5261, 5422, 4111, 5812, 5813, 5462, 5399, 5499}
# Adding initial node emission:5541 185288.98 for motif 102
# {7523, 5541, 5261, 5422, 4111, 5812, 5813, 5462, 5399, 5499}
# Adding initial node emission:5541 185288.98 for motif 98
# {7523, 5541, 5261, 5422, 4111, 5812, 5813, 5462, 5399, 5499}
# Adding initial node emission:5541 185288.98 for motif 38
# {7523, 5541, 5261, 5422, 4111, 5812, 5813, 5462, 5399, 5499}
# Adding initial node emission:5541 185288.98 for motif 6
# {7523, 5541, 5261, 5422, 4111, 5812, 5813, 5462, 5399, 5499}
# Adding initial node emission:5541 185288.98 for motif 108
# {7523, 5541, 5261, 5422, 4111, 5812, 5813, 5462, 5399, 5499}
# Adding initial node emission:5541 185288.98 for motif 14
# {7523, 5541, 5261, 5422, 4111, 5812, 5813, 5462, 5399, 5499}
# Adding initial node emission:5541 185288.98 for motif 46
# {7523, 5541, 5261, 5422, 4111, 5812, 5813, 5462, 5399, 5499}
# Adding initial node emission:5541 370577.96 for motif 78
# {7523, 5541, 5261, 5422, 4111, 5812, 5813, 5462, 5399, 5499}
# Adding initial node emission:5541 185288.98 for motif 238
# {7523, 5541, 5261, 5422, 4111, 5812, 5813, 5462, 5399, 5499}
# Adding initial node emission:5814 33338.9325 for motif 6
# {7523, 5541, 5261, 5422, 4111, 5812, 5813, 5462, 5399, 5814, 5499}
# Adding initial node emission:5814 33338.9325 for motif 12
# {7523, 5541, 5261, 5422, 4111, 5812, 5813, 5462, 5399, 5814, 5499}
# Adding initial node emission:5814 33338.9325 for motif 14
# {7523, 5541, 5261, 5422, 4111, 5812, 5813, 5462, 5399, 5814, 5499}
# Adding initial node emission:5814 33338.9325 for motif 46
# {7523, 5541, 5261, 5422, 4111, 5812, 5813, 5462, 5399, 5814, 5499}
# Adding initial node emission:5814 33338.9325 for motif 98
# {7523, 5541, 5261, 5422, 4111, 5812, 5813, 5462, 5399, 5814, 5499}
# Adding initial node emission:5814 33338.9325 for motif 102
# {7523, 5541, 5261, 5422, 4111, 5812, 5813, 5462, 5399, 5814, 5499}
# Adding initial node emission:5814 33338.9325 for motif 108
# {7523, 5541, 5261, 5422, 4111, 5812, 5813, 5462, 5399, 5814, 5499}
# Adding initial node emission:5814 66677.865 for motif 36
# {7523, 5541, 5261, 5422, 4111, 5812, 5813, 5462, 5399, 5814, 5499}
# Adding initial node emission:5814 33338.9325 for motif 38
# {7523, 5541, 5261, 5422, 4111, 5812, 5813, 5462, 5399, 5814, 5499}
# Adding initial node emission:5814 33338.9325 for motif 74
# {7523, 5541, 5261, 5422, 4111, 5812, 5813, 5462, 5399, 5814, 5499}
# Adding initial node emission:5814 66677.865 for motif 78
# {7523, 5541, 5261, 5422, 4111, 5812, 5813, 5462, 5399, 5814, 5499}
# Adding initial node emission:5814 33338.9325 for motif 238
# {7523, 5541, 5261, 5422, 4111, 5812, 5813, 5462, 5399, 5814, 5499}
# Adding initial node emission:5994 22309.530000000002 for motif 14
# {7523, 5541, 5994, 5261, 5422, 4111, 5812, 5813, 5462, 5399, 5814, 5499}
# Adding initial node emission:5994 22309.530000000002 for motif 46
# {7523, 5541, 5994, 5261, 5422, 4111, 5812, 5813, 5462, 5399, 5814, 5499}
# Adding initial node emission:5994 22309.530000000002 for motif 74
# {7523, 5541, 5994, 5261, 5422, 4111, 5812, 5813, 5462, 5399, 5814, 5499}
# Adding initial node emission:5994 44619.060000000005 for motif 78
# {7523, 5541, 5994, 5261, 5422, 4111, 5812, 5813, 5462, 5399, 5814, 5499}
# Adding initial node emission:5994 22309.530000000002 for motif 102
# {7523, 5541, 5994, 5261, 5422, 4111, 5812, 5813, 5462, 5399, 5814, 5499}
# Adding initial node emission:5994 22309.530000000002 for motif 238
# {7523, 5541, 5994, 5261, 5422, 4111, 5812, 5813, 5462, 5399, 5814, 5499}
# Adding initial node emission:5994 22309.530000000002 for motif 98
# {7523, 5541, 5994, 5261, 5422, 4111, 5812, 5813, 5462, 5399, 5814, 5499}
# Adding initial node emission:5994 44619.060000000005 for motif 36
# {7523, 5541, 5994, 5261, 5422, 4111, 5812, 5813, 5462, 5399, 5814, 5499}
# Adding initial node emission:5994 22309.530000000002 for motif 38
# {7523, 5541, 5994, 5261, 5422, 4111, 5812, 5813, 5462, 5399, 5814, 5499}
# Adding initial node emission:5994 22309.530000000002 for motif 6
# {7523, 5541, 5994, 5261, 5422, 4111, 5812, 5813, 5462, 5399, 5814, 5499}
# Adding initial node emission:5994 22309.530000000002 for motif 12
# {7523, 5541, 5994, 5261, 5422, 4111, 5812, 5813, 5462, 5399, 5814, 5499}
# Adding initial node emission:5994 22309.530000000002 for motif 108
# {7523, 5541, 5994, 5261, 5422, 4111, 5812, 5813, 5462, 5399, 5814, 5499}
# Adding initial node emission:5999 23986.9 for motif 14
# {7523, 5541, 5994, 5261, 5422, 4111, 5999, 5812, 5813, 5462, 5399, 5814, 5499}
# Adding initial node emission:5999 23986.9 for motif 74
# {7523, 5541, 5994, 5261, 5422, 4111, 5999, 5812, 5813, 5462, 5399, 5814, 5499}
# Adding initial node emission:5999 47973.8 for motif 78
# {7523, 5541, 5994, 5261, 5422, 4111, 5999, 5812, 5813, 5462, 5399, 5814, 5499}
# Adding initial node emission:5999 23986.9 for motif 108
# {7523, 5541, 5994, 5261, 5422, 4111, 5999, 5812, 5813, 5462, 5399, 5814, 5499}
# Adding initial node emission:5999 23986.9 for motif 238
# {7523, 5541, 5994, 5261, 5422, 4111, 5999, 5812, 5813, 5462, 5399, 5814, 5499}
# Adding initial node emission:5999 23986.9 for motif 98
# {7523, 5541, 5994, 5261, 5422, 4111, 5999, 5812, 5813, 5462, 5399, 5814, 5499}
# Adding initial node emission:5999 47973.8 for motif 36
# {7523, 5541, 5994, 5261, 5422, 4111, 5999, 5812, 5813, 5462, 5399, 5814, 5499}
# Adding initial node emission:5999 23986.9 for motif 38
# {7523, 5541, 5994, 5261, 5422, 4111, 5999, 5812, 5813, 5462, 5399, 5814, 5499}
# Adding initial node emission:5999 23986.9 for motif 6
# {7523, 5541, 5994, 5261, 5422, 4111, 5999, 5812, 5813, 5462, 5399, 5814, 5499}
# Adding initial node emission:5999 23986.9 for motif 102
# {7523, 5541, 5994, 5261, 5422, 4111, 5999, 5812, 5813, 5462, 5399, 5814, 5499}
# Adding initial node emission:5999 23986.9 for motif 12
# {7523, 5541, 5994, 5261, 5422, 4111, 5999, 5812, 5813, 5462, 5399, 5814, 5499}
# Adding initial node emission:5999 23986.9 for motif 46
# {7523, 5541, 5994, 5261, 5422, 4111, 5999, 5812, 5813, 5462, 5399, 5814, 5499}
# Adding initial node emission:5912 14963.8625 for motif 14
# {7523, 5541, 5994, 5261, 5422, 4111, 5999, 5912, 5812, 5813, 5462, 5399, 5814, 5499}
# Adding initial node emission:5912 14963.8625 for motif 74
# {7523, 5541, 5994, 5261, 5422, 4111, 5999, 5912, 5812, 5813, 5462, 5399, 5814, 5499}
# Adding initial node emission:5912 29927.725 for motif 78
# {7523, 5541, 5994, 5261, 5422, 4111, 5999, 5912, 5812, 5813, 5462, 5399, 5814, 5499}
# Adding initial node emission:5912 14963.8625 for motif 102
# {7523, 5541, 5994, 5261, 5422, 4111, 5999, 5912, 5812, 5813, 5462, 5399, 5814, 5499}
# Adding initial node emission:5912 14963.8625 for motif 238
# {7523, 5541, 5994, 5261, 5422, 4111, 5999, 5912, 5812, 5813, 5462, 5399, 5814, 5499}
# Adding initial node emission:5912 14963.8625 for motif 98
# {7523, 5541, 5994, 5261, 5422, 4111, 5999, 5912, 5812, 5813, 5462, 5399, 5814, 5499}
# Adding initial node emission:5912 29927.725 for motif 36
# {7523, 5541, 5994, 5261, 5422, 4111, 5999, 5912, 5812, 5813, 5462, 5399, 5814, 5499}
# Adding initial node emission:5912 14963.8625 for motif 38
# {7523, 5541, 5994, 5261, 5422, 4111, 5999, 5912, 5812, 5813, 5462, 5399, 5814, 5499}
# Adding initial node emission:5912 14963.8625 for motif 6
# {7523, 5541, 5994, 5261, 5422, 4111, 5999, 5912, 5812, 5813, 5462, 5399, 5814, 5499}
# Adding initial node emission:5912 14963.8625 for motif 12
# {7523, 5541, 5994, 5261, 5422, 4111, 5999, 5912, 5812, 5813, 5462, 5399, 5814, 5499}
# Adding initial node emission:5912 14963.8625 for motif 108
# {7523, 5541, 5994, 5261, 5422, 4111, 5999, 5912, 5812, 5813, 5462, 5399, 5814, 5499}
# Adding initial node emission:5912 14963.8625 for motif 46
# {7523, 5541, 5994, 5261, 5422, 4111, 5999, 5912, 5812, 5813, 5462, 5399, 5814, 5499}
# Adding initial node emission:5945 87794.81999999999 for motif 12
# {7523, 5541, 5994, 5261, 5422, 4111, 5999, 5912, 5812, 5813, 5462, 5399, 5814, 5945, 5499}
# Adding initial node emission:5945 175589.63999999998 for motif 36
# {7523, 5541, 5994, 5261, 5422, 4111, 5999, 5912, 5812, 5813, 5462, 5399, 5814, 5945, 5499}
# Adding initial node emission:5945 87794.81999999999 for motif 74
# {7523, 5541, 5994, 5261, 5422, 4111, 5999, 5912, 5812, 5813, 5462, 5399, 5814, 5945, 5499}
# Adding initial node emission:5945 87794.81999999999 for motif 102
# {7523, 5541, 5994, 5261, 5422, 4111, 5999, 5912, 5812, 5813, 5462, 5399, 5814, 5945, 5499}
# Adding initial node emission:5945 87794.81999999999 for motif 98
# {7523, 5541, 5994, 5261, 5422, 4111, 5999, 5912, 5812, 5813, 5462, 5399, 5814, 5945, 5499}
# Adding initial node emission:5945 87794.81999999999 for motif 38
# {7523, 5541, 5994, 5261, 5422, 4111, 5999, 5912, 5812, 5813, 5462, 5399, 5814, 5945, 5499}
# Adding initial node emission:5945 87794.81999999999 for motif 6
# {7523, 5541, 5994, 5261, 5422, 4111, 5999, 5912, 5812, 5813, 5462, 5399, 5814, 5945, 5499}
# Adding initial node emission:5945 87794.81999999999 for motif 108
# {7523, 5541, 5994, 5261, 5422, 4111, 5999, 5912, 5812, 5813, 5462, 5399, 5814, 5945, 5499}
# Adding initial node emission:5945 87794.81999999999 for motif 14
# {7523, 5541, 5994, 5261, 5422, 4111, 5999, 5912, 5812, 5813, 5462, 5399, 5814, 5945, 5499}
# Adding initial node emission:5945 87794.81999999999 for motif 46
# {7523, 5541, 5994, 5261, 5422, 4111, 5999, 5912, 5812, 5813, 5462, 5399, 5814, 5945, 5499}
# Adding initial node emission:5945 175589.63999999998 for motif 78
# {7523, 5541, 5994, 5261, 5422, 4111, 5999, 5912, 5812, 5813, 5462, 5399, 5814, 5945, 5499}
# Adding initial node emission:5945 87794.81999999999 for motif 238
# {7523, 5541, 5994, 5261, 5422, 4111, 5999, 5912, 5812, 5813, 5462, 5399, 5814, 5945, 5499}
# Adding initial node emission:8299 16264.34 for motif 14
# {7523, 5541, 5994, 8299, 5261, 5422, 4111, 5999, 5912, 5812, 5813, 5462, 5399, 5814, 5945, 5499}
# Adding initial node emission:8299 16264.34 for motif 74
# {7523, 5541, 5994, 8299, 5261, 5422, 4111, 5999, 5912, 5812, 5813, 5462, 5399, 5814, 5945, 5499}
# Adding initial node emission:8299 32528.68 for motif 78
# {7523, 5541, 5994, 8299, 5261, 5422, 4111, 5999, 5912, 5812, 5813, 5462, 5399, 5814, 5945, 5499}
# Adding initial node emission:8299 16264.34 for motif 238
# {7523, 5541, 5994, 8299, 5261, 5422, 4111, 5999, 5912, 5812, 5813, 5462, 5399, 5814, 5945, 5499}
# Adding initial node emission:8299 16264.34 for motif 98
# {7523, 5541, 5994, 8299, 5261, 5422, 4111, 5999, 5912, 5812, 5813, 5462, 5399, 5814, 5945, 5499}
# Adding initial node emission:8299 32528.68 for motif 36
# {7523, 5541, 5994, 8299, 5261, 5422, 4111, 5999, 5912, 5812, 5813, 5462, 5399, 5814, 5945, 5499}
# Adding initial node emission:8299 16264.34 for motif 38
# {7523, 5541, 5994, 8299, 5261, 5422, 4111, 5999, 5912, 5812, 5813, 5462, 5399, 5814, 5945, 5499}
# Adding initial node emission:8299 16264.34 for motif 6
# {7523, 5541, 5994, 8299, 5261, 5422, 4111, 5999, 5912, 5812, 5813, 5462, 5399, 5814, 5945, 5499}
# Adding initial node emission:8299 16264.34 for motif 102
# {7523, 5541, 5994, 8299, 5261, 5422, 4111, 5999, 5912, 5812, 5813, 5462, 5399, 5814, 5945, 5499}
# Adding initial node emission:8299 16264.34 for motif 12
# {7523, 5541, 5994, 8299, 5261, 5422, 4111, 5999, 5912, 5812, 5813, 5462, 5399, 5814, 5945, 5499}
# Adding initial node emission:8299 16264.34 for motif 108
# {7523, 5541, 5994, 8299, 5261, 5422, 4111, 5999, 5912, 5812, 5813, 5462, 5399, 5814, 5945, 5499}
# Adding initial node emission:8299 16264.34 for motif 46
# {7523, 5541, 5994, 8299, 5261, 5422, 4111, 5999, 5912, 5812, 5813, 5462, 5399, 5814, 5945, 5499}
# Adding initial node emission:5811 34005.7025 for motif 12
# {7523, 5541, 5994, 8299, 5261, 5422, 4111, 5999, 5912, 5811, 5812, 5813, 5462, 5399, 5814, 5945, 5499}
# Adding initial node emission:5811 68011.405 for motif 36
# {7523, 5541, 5994, 8299, 5261, 5422, 4111, 5999, 5912, 5811, 5812, 5813, 5462, 5399, 5814, 5945, 5499}
# Adding initial node emission:5811 34005.7025 for motif 74
# {7523, 5541, 5994, 8299, 5261, 5422, 4111, 5999, 5912, 5811, 5812, 5813, 5462, 5399, 5814, 5945, 5499}
# Adding initial node emission:5811 34005.7025 for motif 102
# {7523, 5541, 5994, 8299, 5261, 5422, 4111, 5999, 5912, 5811, 5812, 5813, 5462, 5399, 5814, 5945, 5499}
# Adding initial node emission:5811 34005.7025 for motif 98
# {7523, 5541, 5994, 8299, 5261, 5422, 4111, 5999, 5912, 5811, 5812, 5813, 5462, 5399, 5814, 5945, 5499}
# Adding initial node emission:5811 34005.7025 for motif 38
# {7523, 5541, 5994, 8299, 5261, 5422, 4111, 5999, 5912, 5811, 5812, 5813, 5462, 5399, 5814, 5945, 5499}
# Adding initial node emission:5811 34005.7025 for motif 6
# {7523, 5541, 5994, 8299, 5261, 5422, 4111, 5999, 5912, 5811, 5812, 5813, 5462, 5399, 5814, 5945, 5499}
# Adding initial node emission:5811 34005.7025 for motif 108
# {7523, 5541, 5994, 8299, 5261, 5422, 4111, 5999, 5912, 5811, 5812, 5813, 5462, 5399, 5814, 5945, 5499}
# Adding initial node emission:5811 34005.7025 for motif 14
# {7523, 5541, 5994, 8299, 5261, 5422, 4111, 5999, 5912, 5811, 5812, 5813, 5462, 5399, 5814, 5945, 5499}
# Adding initial node emission:5811 34005.7025 for motif 46
# {7523, 5541, 5994, 8299, 5261, 5422, 4111, 5999, 5912, 5811, 5812, 5813, 5462, 5399, 5814, 5945, 5499}
# Adding initial node emission:5811 68011.405 for motif 78
# {7523, 5541, 5994, 8299, 5261, 5422, 4111, 5999, 5912, 5811, 5812, 5813, 5462, 5399, 5814, 5945, 5499}
# Adding initial node emission:5811 34005.7025 for motif 238
# {7523, 5541, 5994, 8299, 5261, 5422, 4111, 5999, 5912, 5811, 5812, 5813, 5462, 5399, 5814, 5945, 5499}
# Adding initial node emission:5734 11925.65 for motif 6
# {7523, 5541, 5734, 5994, 8299, 5261, 5422, 4111, 5999, 5912, 5811, 5812, 5813, 5462, 5399, 5814, 5945, 5499}
# Adding initial node emission:5734 11925.65 for motif 12
# {7523, 5541, 5734, 5994, 8299, 5261, 5422, 4111, 5999, 5912, 5811, 5812, 5813, 5462, 5399, 5814, 5945, 5499}
# Adding initial node emission:5734 11925.65 for motif 38
# {7523, 5541, 5734, 5994, 8299, 5261, 5422, 4111, 5999, 5912, 5811, 5812, 5813, 5462, 5399, 5814, 5945, 5499}
# Adding initial node emission:5734 11925.65 for motif 74
# {7523, 5541, 5734, 5994, 8299, 5261, 5422, 4111, 5999, 5912, 5811, 5812, 5813, 5462, 5399, 5814, 5945, 5499}
# Adding initial node emission:5734 11925.65 for motif 98
# {7523, 5541, 5734, 5994, 8299, 5261, 5422, 4111, 5999, 5912, 5811, 5812, 5813, 5462, 5399, 5814, 5945, 5499}
# Adding initial node emission:5734 23851.3 for motif 36
# {7523, 5541, 5734, 5994, 8299, 5261, 5422, 4111, 5999, 5912, 5811, 5812, 5813, 5462, 5399, 5814, 5945, 5499}
# Adding initial node emission:5734 11925.65 for motif 102
# {7523, 5541, 5734, 5994, 8299, 5261, 5422, 4111, 5999, 5912, 5811, 5812, 5813, 5462, 5399, 5814, 5945, 5499}
# Adding initial node emission:5734 11925.65 for motif 108
# {7523, 5541, 5734, 5994, 8299, 5261, 5422, 4111, 5999, 5912, 5811, 5812, 5813, 5462, 5399, 5814, 5945, 5499}
# Adding initial node emission:5734 11925.65 for motif 14
# {7523, 5541, 5734, 5994, 8299, 5261, 5422, 4111, 5999, 5912, 5811, 5812, 5813, 5462, 5399, 5814, 5945, 5499}
# Adding initial node emission:5734 11925.65 for motif 46
# {7523, 5541, 5734, 5994, 8299, 5261, 5422, 4111, 5999, 5912, 5811, 5812, 5813, 5462, 5399, 5814, 5945, 5499}
# Adding initial node emission:5734 23851.3 for motif 78
# {7523, 5541, 5734, 5994, 8299, 5261, 5422, 4111, 5999, 5912, 5811, 5812, 5813, 5462, 5399, 5814, 5945, 5499}
# Adding initial node emission:5734 11925.65 for motif 238
# {7523, 5541, 5734, 5994, 8299, 5261, 5422, 4111, 5999, 5912, 5811, 5812, 5813, 5462, 5399, 5814, 5945, 5499}
# Adding initial node emission:5651 2921.28 for motif 12
# {5261, 4111, 5651, 5399, 5912, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 5462, 7523, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:5651 5842.56 for motif 36
# {5261, 4111, 5651, 5399, 5912, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 5462, 7523, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:5651 2921.28 for motif 74
# {5261, 4111, 5651, 5399, 5912, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 5462, 7523, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:5651 2921.28 for motif 98
# {5261, 4111, 5651, 5399, 5912, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 5462, 7523, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:5651 2921.28 for motif 38
# {5261, 4111, 5651, 5399, 5912, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 5462, 7523, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:5651 2921.28 for motif 6
# {5261, 4111, 5651, 5399, 5912, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 5462, 7523, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:5651 2921.28 for motif 102
# {5261, 4111, 5651, 5399, 5912, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 5462, 7523, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:5651 2921.28 for motif 108
# {5261, 4111, 5651, 5399, 5912, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 5462, 7523, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:5651 2921.28 for motif 14
# {5261, 4111, 5651, 5399, 5912, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 5462, 7523, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:5651 2921.28 for motif 46
# {5261, 4111, 5651, 5399, 5912, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 5462, 7523, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:5651 5842.56 for motif 78
# {5261, 4111, 5651, 5399, 5912, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 5462, 7523, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:5651 2921.28 for motif 238
# {5261, 4111, 5651, 5399, 5912, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 5462, 7523, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:7011 105823.8711111111 for motif 6
# {5261, 4111, 5651, 5399, 5912, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 5462, 7523, 7011, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:7011 105823.8711111111 for motif 12
# {5261, 4111, 5651, 5399, 5912, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 5462, 7523, 7011, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:7011 211647.7422222222 for motif 36
# {5261, 4111, 5651, 5399, 5912, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 5462, 7523, 7011, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:7011 105823.8711111111 for motif 38
# {5261, 4111, 5651, 5399, 5912, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 5462, 7523, 7011, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:7011 105823.8711111111 for motif 102
# {5261, 4111, 5651, 5399, 5912, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 5462, 7523, 7011, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:7011 105823.8711111111 for motif 98
# {5261, 4111, 5651, 5399, 5912, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 5462, 7523, 7011, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:7011 105823.8711111111 for motif 74
# {5261, 4111, 5651, 5399, 5912, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 5462, 7523, 7011, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:7011 105823.8711111111 for motif 108
# {5261, 4111, 5651, 5399, 5912, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 5462, 7523, 7011, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:7011 105823.8711111111 for motif 14
# {5261, 4111, 5651, 5399, 5912, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 5462, 7523, 7011, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:7011 105823.8711111111 for motif 46
# {5261, 4111, 5651, 5399, 5912, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 5462, 7523, 7011, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:7011 211647.7422222222 for motif 78
# {5261, 4111, 5651, 5399, 5912, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 5462, 7523, 7011, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:7011 105823.8711111111 for motif 238
# {5261, 4111, 5651, 5399, 5912, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 5462, 7523, 7011, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:7230 2532.57 for motif 12
# {5261, 4111, 5651, 5399, 5912, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 7230, 5462, 7523, 7011, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:7230 5065.14 for motif 36
# {5261, 4111, 5651, 5399, 5912, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 7230, 5462, 7523, 7011, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:7230 2532.57 for motif 74
# {5261, 4111, 5651, 5399, 5912, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 7230, 5462, 7523, 7011, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:7230 2532.57 for motif 102
# {5261, 4111, 5651, 5399, 5912, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 7230, 5462, 7523, 7011, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:7230 2532.57 for motif 98
# {5261, 4111, 5651, 5399, 5912, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 7230, 5462, 7523, 7011, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:7230 2532.57 for motif 38
# {5261, 4111, 5651, 5399, 5912, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 7230, 5462, 7523, 7011, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:7230 2532.57 for motif 6
# {5261, 4111, 5651, 5399, 5912, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 7230, 5462, 7523, 7011, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:7230 2532.57 for motif 108
# {5261, 4111, 5651, 5399, 5912, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 7230, 5462, 7523, 7011, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:7230 2532.57 for motif 14
# {5261, 4111, 5651, 5399, 5912, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 7230, 5462, 7523, 7011, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:7230 2532.57 for motif 46
# {5261, 4111, 5651, 5399, 5912, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 7230, 5462, 7523, 7011, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:7230 5065.14 for motif 78
# {5261, 4111, 5651, 5399, 5912, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 7230, 5462, 7523, 7011, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:7230 2532.57 for motif 238
# {5261, 4111, 5651, 5399, 5912, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 7230, 5462, 7523, 7011, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:6011 331587.48 for motif 6
# {5261, 4111, 5651, 5399, 5912, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 7230, 5462, 7523, 7011, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:6011 331587.48 for motif 12
# {5261, 4111, 5651, 5399, 5912, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 7230, 5462, 7523, 7011, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:6011 331587.48 for motif 38
# {5261, 4111, 5651, 5399, 5912, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 7230, 5462, 7523, 7011, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:6011 331587.48 for motif 98
# {5261, 4111, 5651, 5399, 5912, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 7230, 5462, 7523, 7011, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:6011 663174.96 for motif 36
# {5261, 4111, 5651, 5399, 5912, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 7230, 5462, 7523, 7011, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:6011 331587.48 for motif 102
# {5261, 4111, 5651, 5399, 5912, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 7230, 5462, 7523, 7011, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:6011 331587.48 for motif 74
# {5261, 4111, 5651, 5399, 5912, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 7230, 5462, 7523, 7011, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:6011 331587.48 for motif 108
# {5261, 4111, 5651, 5399, 5912, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 7230, 5462, 7523, 7011, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:6011 331587.48 for motif 14
# {5261, 4111, 5651, 5399, 5912, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 7230, 5462, 7523, 7011, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:6011 331587.48 for motif 46
# {5261, 4111, 5651, 5399, 5912, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 7230, 5462, 7523, 7011, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:6011 663174.96 for motif 78
# {5261, 4111, 5651, 5399, 5912, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 7230, 5462, 7523, 7011, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:6011 331587.48 for motif 238
# {5261, 4111, 5651, 5399, 5912, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 7230, 5462, 7523, 7011, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:7941 24308.22 for motif 12
# {7941, 5261, 4111, 5651, 5399, 5912, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 7230, 5462, 7523, 7011, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:7941 48616.44 for motif 36
# {7941, 5261, 4111, 5651, 5399, 5912, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 7230, 5462, 7523, 7011, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:7941 24308.22 for motif 38
# {7941, 5261, 4111, 5651, 5399, 5912, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 7230, 5462, 7523, 7011, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:7941 24308.22 for motif 74
# {7941, 5261, 4111, 5651, 5399, 5912, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 7230, 5462, 7523, 7011, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:7941 24308.22 for motif 102
# {7941, 5261, 4111, 5651, 5399, 5912, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 7230, 5462, 7523, 7011, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:7941 24308.22 for motif 98
# {7941, 5261, 4111, 5651, 5399, 5912, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 7230, 5462, 7523, 7011, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:7941 24308.22 for motif 6
# {7941, 5261, 4111, 5651, 5399, 5912, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 7230, 5462, 7523, 7011, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:7941 24308.22 for motif 108
# {7941, 5261, 4111, 5651, 5399, 5912, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 7230, 5462, 7523, 7011, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:7941 24308.22 for motif 14
# {7941, 5261, 4111, 5651, 5399, 5912, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 7230, 5462, 7523, 7011, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:7941 24308.22 for motif 46
# {7941, 5261, 4111, 5651, 5399, 5912, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 7230, 5462, 7523, 7011, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:7941 48616.44 for motif 78
# {7941, 5261, 4111, 5651, 5399, 5912, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 7230, 5462, 7523, 7011, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:7941 24308.22 for motif 238
# {7941, 5261, 4111, 5651, 5399, 5912, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 7230, 5462, 7523, 7011, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:7997 50078.649999999994 for motif 12
# {7941, 5261, 4111, 5651, 5399, 5912, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 7997, 7230, 5462, 7523, 7011, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:7997 100157.29999999999 for motif 36
# {7941, 5261, 4111, 5651, 5399, 5912, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 7997, 7230, 5462, 7523, 7011, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:7997 50078.649999999994 for motif 74
# {7941, 5261, 4111, 5651, 5399, 5912, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 7997, 7230, 5462, 7523, 7011, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:7997 50078.649999999994 for motif 102
# {7941, 5261, 4111, 5651, 5399, 5912, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 7997, 7230, 5462, 7523, 7011, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:7997 50078.649999999994 for motif 108
# {7941, 5261, 4111, 5651, 5399, 5912, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 7997, 7230, 5462, 7523, 7011, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:7997 50078.649999999994 for motif 98
# {7941, 5261, 4111, 5651, 5399, 5912, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 7997, 7230, 5462, 7523, 7011, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:7997 50078.649999999994 for motif 38
# {7941, 5261, 4111, 5651, 5399, 5912, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 7997, 7230, 5462, 7523, 7011, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:7997 50078.649999999994 for motif 6
# {7941, 5261, 4111, 5651, 5399, 5912, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 7997, 7230, 5462, 7523, 7011, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:7997 50078.649999999994 for motif 14
# {7941, 5261, 4111, 5651, 5399, 5912, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 7997, 7230, 5462, 7523, 7011, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:7997 50078.649999999994 for motif 46
# {7941, 5261, 4111, 5651, 5399, 5912, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 7997, 7230, 5462, 7523, 7011, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:7997 100157.29999999999 for motif 78
# {7941, 5261, 4111, 5651, 5399, 5912, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 7997, 7230, 5462, 7523, 7011, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:7997 50078.649999999994 for motif 238
# {7941, 5261, 4111, 5651, 5399, 5912, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 7997, 7230, 5462, 7523, 7011, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:5310 34086.36 for motif 12
# {7941, 5261, 4111, 5651, 5399, 5912, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 7997, 7230, 5310, 5462, 7523, 7011, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:5310 68172.72 for motif 36
# {7941, 5261, 4111, 5651, 5399, 5912, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 7997, 7230, 5310, 5462, 7523, 7011, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:5310 34086.36 for motif 74
# {7941, 5261, 4111, 5651, 5399, 5912, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 7997, 7230, 5310, 5462, 7523, 7011, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:5310 34086.36 for motif 102
# {7941, 5261, 4111, 5651, 5399, 5912, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 7997, 7230, 5310, 5462, 7523, 7011, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:5310 34086.36 for motif 98
# {7941, 5261, 4111, 5651, 5399, 5912, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 7997, 7230, 5310, 5462, 7523, 7011, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:5310 34086.36 for motif 38
# {7941, 5261, 4111, 5651, 5399, 5912, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 7997, 7230, 5310, 5462, 7523, 7011, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:5310 34086.36 for motif 6
# {7941, 5261, 4111, 5651, 5399, 5912, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 7997, 7230, 5310, 5462, 7523, 7011, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:5310 34086.36 for motif 108
# {7941, 5261, 4111, 5651, 5399, 5912, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 7997, 7230, 5310, 5462, 7523, 7011, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:5310 34086.36 for motif 14
# {7941, 5261, 4111, 5651, 5399, 5912, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 7997, 7230, 5310, 5462, 7523, 7011, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:5310 34086.36 for motif 46
# {7941, 5261, 4111, 5651, 5399, 5912, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 7997, 7230, 5310, 5462, 7523, 7011, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:5310 68172.72 for motif 78
# {7941, 5261, 4111, 5651, 5399, 5912, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 7997, 7230, 5310, 5462, 7523, 7011, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:5310 34086.36 for motif 238
# {7941, 5261, 4111, 5651, 5399, 5912, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 7997, 7230, 5310, 5462, 7523, 7011, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:5712 30882.96 for motif 12
# {7941, 5261, 4111, 5651, 5399, 5912, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 7997, 7230, 5310, 5712, 5462, 7523, 7011, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:5712 61765.92 for motif 36
# {7941, 5261, 4111, 5651, 5399, 5912, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 7997, 7230, 5310, 5712, 5462, 7523, 7011, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:5712 30882.96 for motif 74
# {7941, 5261, 4111, 5651, 5399, 5912, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 7997, 7230, 5310, 5712, 5462, 7523, 7011, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:5712 30882.96 for motif 102
# {7941, 5261, 4111, 5651, 5399, 5912, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 7997, 7230, 5310, 5712, 5462, 7523, 7011, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:5712 30882.96 for motif 98
# {7941, 5261, 4111, 5651, 5399, 5912, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 7997, 7230, 5310, 5712, 5462, 7523, 7011, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:5712 30882.96 for motif 38
# {7941, 5261, 4111, 5651, 5399, 5912, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 7997, 7230, 5310, 5712, 5462, 7523, 7011, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:5712 30882.96 for motif 6
# {7941, 5261, 4111, 5651, 5399, 5912, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 7997, 7230, 5310, 5712, 5462, 7523, 7011, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:5712 30882.96 for motif 108
# {7941, 5261, 4111, 5651, 5399, 5912, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 7997, 7230, 5310, 5712, 5462, 7523, 7011, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:5712 30882.96 for motif 14
# {7941, 5261, 4111, 5651, 5399, 5912, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 7997, 7230, 5310, 5712, 5462, 7523, 7011, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:5712 30882.96 for motif 46
# {7941, 5261, 4111, 5651, 5399, 5912, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 7997, 7230, 5310, 5712, 5462, 7523, 7011, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:5712 61765.92 for motif 78
# {7941, 5261, 4111, 5651, 5399, 5912, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 7997, 7230, 5310, 5712, 5462, 7523, 7011, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:5712 30882.96 for motif 238
# {7941, 5261, 4111, 5651, 5399, 5912, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 7997, 7230, 5310, 5712, 5462, 7523, 7011, 5734, 5994, 8299, 5999, 5499}
# Adding initial node emission:5992 220439.36 for motif 6
# {7941, 5261, 4111, 5651, 5399, 5912, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 7997, 7230, 5310, 5712, 5462, 7523, 7011, 5734, 5992, 5994, 8299, 5999, 5499}
# Adding initial node emission:5992 220439.36 for motif 12
# {7941, 5261, 4111, 5651, 5399, 5912, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 7997, 7230, 5310, 5712, 5462, 7523, 7011, 5734, 5992, 5994, 8299, 5999, 5499}
# Adding initial node emission:5992 440878.72 for motif 36
# {7941, 5261, 4111, 5651, 5399, 5912, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 7997, 7230, 5310, 5712, 5462, 7523, 7011, 5734, 5992, 5994, 8299, 5999, 5499}
# Adding initial node emission:5992 220439.36 for motif 98
# {7941, 5261, 4111, 5651, 5399, 5912, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 7997, 7230, 5310, 5712, 5462, 7523, 7011, 5734, 5992, 5994, 8299, 5999, 5499}
# Adding initial node emission:5992 220439.36 for motif 102
# {7941, 5261, 4111, 5651, 5399, 5912, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 7997, 7230, 5310, 5712, 5462, 7523, 7011, 5734, 5992, 5994, 8299, 5999, 5499}
# Adding initial node emission:5992 220439.36 for motif 108
# {7941, 5261, 4111, 5651, 5399, 5912, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 7997, 7230, 5310, 5712, 5462, 7523, 7011, 5734, 5992, 5994, 8299, 5999, 5499}
# Adding initial node emission:5992 220439.36 for motif 38
# {7941, 5261, 4111, 5651, 5399, 5912, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 7997, 7230, 5310, 5712, 5462, 7523, 7011, 5734, 5992, 5994, 8299, 5999, 5499}
# Adding initial node emission:5992 220439.36 for motif 74
# {7941, 5261, 4111, 5651, 5399, 5912, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 7997, 7230, 5310, 5712, 5462, 7523, 7011, 5734, 5992, 5994, 8299, 5999, 5499}
# Adding initial node emission:5992 220439.36 for motif 14
# {7941, 5261, 4111, 5651, 5399, 5912, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 7997, 7230, 5310, 5712, 5462, 7523, 7011, 5734, 5992, 5994, 8299, 5999, 5499}
# Adding initial node emission:5992 220439.36 for motif 46
# {7941, 5261, 4111, 5651, 5399, 5912, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 7997, 7230, 5310, 5712, 5462, 7523, 7011, 5734, 5992, 5994, 8299, 5999, 5499}
# Adding initial node emission:5992 440878.72 for motif 78
# {7941, 5261, 4111, 5651, 5399, 5912, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 7997, 7230, 5310, 5712, 5462, 7523, 7011, 5734, 5992, 5994, 8299, 5999, 5499}
# Adding initial node emission:5992 220439.36 for motif 238
# {7941, 5261, 4111, 5651, 5399, 5912, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 7997, 7230, 5310, 5712, 5462, 7523, 7011, 5734, 5992, 5994, 8299, 5999, 5499}
# Adding initial node emission:8699 1608422.16 for motif 12
# {7941, 5261, 4111, 5651, 5399, 5912, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 7997, 7230, 5310, 5712, 5462, 7523, 7011, 5734, 5992, 5994, 8299, 5999, 8699, 5499}
# Adding initial node emission:8699 3216844.32 for motif 36
# {7941, 5261, 4111, 5651, 5399, 5912, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 7997, 7230, 5310, 5712, 5462, 7523, 7011, 5734, 5992, 5994, 8299, 5999, 8699, 5499}
# Adding initial node emission:8699 1608422.16 for motif 74
# {7941, 5261, 4111, 5651, 5399, 5912, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 7997, 7230, 5310, 5712, 5462, 7523, 7011, 5734, 5992, 5994, 8299, 5999, 8699, 5499}
# Adding initial node emission:8699 1608422.16 for motif 102
# {7941, 5261, 4111, 5651, 5399, 5912, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 7997, 7230, 5310, 5712, 5462, 7523, 7011, 5734, 5992, 5994, 8299, 5999, 8699, 5499}
# Adding initial node emission:8699 1608422.16 for motif 98
# {7941, 5261, 4111, 5651, 5399, 5912, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 5945, 7997, 7230, 5310, 5712, 5462, 7523, 7011, 5734, 5992, 5994, 8299, 5999, 8699, 5499}
# Adding initial node emission:8699 1608422.16 for motif 38
# ...
# Adding initial node emission:5964 147402.19999999998 for motif 46
# {7941, 5261, 4111, 5651, 5399, 5912, 4121, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 9399, 5941, 5945, 7996, 7997, 7230, 5310, 7999, 5699, 5964, 5712, 5331, 5462, 5719, 7392, 7523, 7011, 5734, 5992, 5994, 8299, 5999, 7538, 8699, 5499}
# Adding initial node emission:5964 294804.39999999997 for motif 78
# {7941, 5261, 4111, 5651, 5399, 5912, 4121, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 9399, 5941, 5945, 7996, 7997, 7230, 5310, 7999, 5699, 5964, 5712, 5331, 5462, 5719, 7392, 7523, 7011, 5734, 5992, 5994, 8299, 5999, 7538, 8699, 5499}
# Adding initial node emission:5964 147402.19999999998 for motif 238
# {7941, 5261, 4111, 5651, 5399, 5912, 4121, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 9399, 5941, 5945, 7996, 7997, 7230, 5310, 7999, 5699, 5964, 5712, 5331, 5462, 5719, 7392, 7523, 7011, 5734, 5992, 5994, 8299, 5999, 7538, 8699, 5499}
# Adding initial node emission:7922 7019.52 for motif 12
# {7941, 5261, 4111, 5651, 5399, 5912, 4121, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 9399, 5941, 5945, 7996, 7997, 7230, 5310, 7999, 5699, 5964, 5712, 5331, 5462, 5719, 7392, 7523, 7011, 5734, 5992, 5994, 8299, 5999, 7538, 7922, 8699, 5499}
# Adding initial node emission:7922 14039.04 for motif 36
# {7941, 5261, 4111, 5651, 5399, 5912, 4121, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 9399, 5941, 5945, 7996, 7997, 7230, 5310, 7999, 5699, 5964, 5712, 5331, 5462, 5719, 7392, 7523, 7011, 5734, 5992, 5994, 8299, 5999, 7538, 7922, 8699, 5499}
# Adding initial node emission:7922 7019.52 for motif 74
# {7941, 5261, 4111, 5651, 5399, 5912, 4121, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 9399, 5941, 5945, 7996, 7997, 7230, 5310, 7999, 5699, 5964, 5712, 5331, 5462, 5719, 7392, 7523, 7011, 5734, 5992, 5994, 8299, 5999, 7538, 7922, 8699, 5499}
# Adding initial node emission:7922 7019.52 for motif 102
# {7941, 5261, 4111, 5651, 5399, 5912, 4121, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 9399, 5941, 5945, 7996, 7997, 7230, 5310, 7999, 5699, 5964, 5712, 5331, 5462, 5719, 7392, 7523, 7011, 5734, 5992, 5994, 8299, 5999, 7538, 7922, 8699, 5499}
# Adding initial node emission:7922 7019.52 for motif 98
# {7941, 5261, 4111, 5651, 5399, 5912, 4121, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 9399, 5941, 5945, 7996, 7997, 7230, 5310, 7999, 5699, 5964, 5712, 5331, 5462, 5719, 7392, 7523, 7011, 5734, 5992, 5994, 8299, 5999, 7538, 7922, 8699, 5499}
# Adding initial node emission:7922 7019.52 for motif 38
# {7941, 5261, 4111, 5651, 5399, 5912, 4121, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 9399, 5941, 5945, 7996, 7997, 7230, 5310, 7999, 5699, 5964, 5712, 5331, 5462, 5719, 7392, 7523, 7011, 5734, 5992, 5994, 8299, 5999, 7538, 7922, 8699, 5499}
# Adding initial node emission:7922 7019.52 for motif 6
# {7941, 5261, 4111, 5651, 5399, 5912, 4121, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 9399, 5941, 5945, 7996, 7997, 7230, 5310, 7999, 5699, 5964, 5712, 5331, 5462, 5719, 7392, 7523, 7011, 5734, 5992, 5994, 8299, 5999, 7538, 7922, 8699, 5499}
# Adding initial node emission:7922 7019.52 for motif 108
# {7941, 5261, 4111, 5651, 5399, 5912, 4121, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 9399, 5941, 5945, 7996, 7997, 7230, 5310, 7999, 5699, 5964, 5712, 5331, 5462, 5719, 7392, 7523, 7011, 5734, 5992, 5994, 8299, 5999, 7538, 7922, 8699, 5499}
# Adding initial node emission:7922 7019.52 for motif 14
# {7941, 5261, 4111, 5651, 5399, 5912, 4121, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 9399, 5941, 5945, 7996, 7997, 7230, 5310, 7999, 5699, 5964, 5712, 5331, 5462, 5719, 7392, 7523, 7011, 5734, 5992, 5994, 8299, 5999, 7538, 7922, 8699, 5499}
# Adding initial node emission:7922 7019.52 for motif 46
# {7941, 5261, 4111, 5651, 5399, 5912, 4121, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 9399, 5941, 5945, 7996, 7997, 7230, 5310, 7999, 5699, 5964, 5712, 5331, 5462, 5719, 7392, 7523, 7011, 5734, 5992, 5994, 8299, 5999, 7538, 7922, 8699, 5499}
# Adding initial node emission:7922 14039.04 for motif 78
# {7941, 5261, 4111, 5651, 5399, 5912, 4121, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 9399, 5941, 5945, 7996, 7997, 7230, 5310, 7999, 5699, 5964, 5712, 5331, 5462, 5719, 7392, 7523, 7011, 5734, 5992, 5994, 8299, 5999, 7538, 7922, 8699, 5499}
# Adding initial node emission:7922 7019.52 for motif 238
# {7941, 5261, 4111, 5651, 5399, 5912, 4121, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 9399, 5941, 5945, 7996, 7997, 7230, 5310, 7999, 5699, 5964, 5712, 5331, 5462, 5719, 7392, 7523, 7011, 5734, 5992, 5994, 8299, 5999, 7538, 7922, 8699, 5499}
# Adding initial node emission:4582 3437900.44 for motif 12
# {7941, 5261, 4111, 5651, 5399, 5912, 4121, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 9399, 5941, 5945, 7996, 7997, 7230, 5310, 7999, 5699, 5964, 5712, 5331, 5462, 5719, 7392, 7523, 7011, 5734, 4582, 5992, 5994, 8299, 5999, 7538, 7922, 8699, 5499}
# Adding initial node emission:4582 6875800.88 for motif 36
# {7941, 5261, 4111, 5651, 5399, 5912, 4121, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 9399, 5941, 5945, 7996, 7997, 7230, 5310, 7999, 5699, 5964, 5712, 5331, 5462, 5719, 7392, 7523, 7011, 5734, 4582, 5992, 5994, 8299, 5999, 7538, 7922, 8699, 5499}
# Adding initial node emission:4582 3437900.44 for motif 74
# {7941, 5261, 4111, 5651, 5399, 5912, 4121, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 9399, 5941, 5945, 7996, 7997, 7230, 5310, 7999, 5699, 5964, 5712, 5331, 5462, 5719, 7392, 7523, 7011, 5734, 4582, 5992, 5994, 8299, 5999, 7538, 7922, 8699, 5499}
# Adding initial node emission:4582 3437900.44 for motif 98
# {7941, 5261, 4111, 5651, 5399, 5912, 4121, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 9399, 5941, 5945, 7996, 7997, 7230, 5310, 7999, 5699, 5964, 5712, 5331, 5462, 5719, 7392, 7523, 7011, 5734, 4582, 5992, 5994, 8299, 5999, 7538, 7922, 8699, 5499}
# Adding initial node emission:4582 3437900.44 for motif 38
# {7941, 5261, 4111, 5651, 5399, 5912, 4121, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 9399, 5941, 5945, 7996, 7997, 7230, 5310, 7999, 5699, 5964, 5712, 5331, 5462, 5719, 7392, 7523, 7011, 5734, 4582, 5992, 5994, 8299, 5999, 7538, 7922, 8699, 5499}
# Adding initial node emission:4582 3437900.44 for motif 6
# {7941, 5261, 4111, 5651, 5399, 5912, 4121, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 9399, 5941, 5945, 7996, 7997, 7230, 5310, 7999, 5699, 5964, 5712, 5331, 5462, 5719, 7392, 7523, 7011, 5734, 4582, 5992, 5994, 8299, 5999, 7538, 7922, 8699, 5499}
# Adding initial node emission:4582 3437900.44 for motif 102
# {7941, 5261, 4111, 5651, 5399, 5912, 4121, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 9399, 5941, 5945, 7996, 7997, 7230, 5310, 7999, 5699, 5964, 5712, 5331, 5462, 5719, 7392, 7523, 7011, 5734, 4582, 5992, 5994, 8299, 5999, 7538, 7922, 8699, 5499}
# Adding initial node emission:4582 3437900.44 for motif 108
# {7941, 5261, 4111, 5651, 5399, 5912, 4121, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 9399, 5941, 5945, 7996, 7997, 7230, 5310, 7999, 5699, 5964, 5712, 5331, 5462, 5719, 7392, 7523, 7011, 5734, 4582, 5992, 5994, 8299, 5999, 7538, 7922, 8699, 5499}
# Adding initial node emission:4582 3437900.44 for motif 14
# {7941, 5261, 4111, 5651, 5399, 5912, 4121, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 9399, 5941, 5945, 7996, 7997, 7230, 5310, 7999, 5699, 5964, 5712, 5331, 5462, 5719, 7392, 7523, 7011, 5734, 4582, 5992, 5994, 8299, 5999, 7538, 7922, 8699, 5499}
# Adding initial node emission:4582 3437900.44 for motif 46
# {7941, 5261, 4111, 5651, 5399, 5912, 4121, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 9399, 5941, 5945, 7996, 7997, 7230, 5310, 7999, 5699, 5964, 5712, 5331, 5462, 5719, 7392, 7523, 7011, 5734, 4582, 5992, 5994, 8299, 5999, 7538, 7922, 8699, 5499}
# Adding initial node emission:4582 6875800.88 for motif 78
# {7941, 5261, 4111, 5651, 5399, 5912, 4121, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 9399, 5941, 5945, 7996, 7997, 7230, 5310, 7999, 5699, 5964, 5712, 5331, 5462, 5719, 7392, 7523, 7011, 5734, 4582, 5992, 5994, 8299, 5999, 7538, 7922, 8699, 5499}
# Adding initial node emission:4582 3437900.44 for motif 238
# {7941, 5261, 4111, 5651, 5399, 5912, 4121, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 9399, 5941, 5945, 7996, 7997, 7230, 5310, 7999, 5699, 5964, 5712, 5331, 5462, 5719, 7392, 7523, 7011, 5734, 4582, 5992, 5994, 8299, 5999, 7538, 7922, 8699, 5499}
# Adding initial node emission:4112 8700.56 for motif 12
# {7941, 5261, 4111, 4112, 5651, 5399, 5912, 4121, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 9399, 5941, 5945, 7996, 7997, 7230, 5310, 7999, 5699, 5964, 5712, 5331, 5462, 5719, 7392, 7523, 7011, 5734, 4582, 5992, 5994, 8299, 5999, 7538, 7922, 8699, 5499}
# Adding initial node emission:4112 17401.12 for motif 36
# {7941, 5261, 4111, 4112, 5651, 5399, 5912, 4121, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 9399, 5941, 5945, 7996, 7997, 7230, 5310, 7999, 5699, 5964, 5712, 5331, 5462, 5719, 7392, 7523, 7011, 5734, 4582, 5992, 5994, 8299, 5999, 7538, 7922, 8699, 5499}
# Adding initial node emission:4112 8700.56 for motif 74
# {7941, 5261, 4111, 4112, 5651, 5399, 5912, 4121, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 9399, 5941, 5945, 7996, 7997, 7230, 5310, 7999, 5699, 5964, 5712, 5331, 5462, 5719, 7392, 7523, 7011, 5734, 4582, 5992, 5994, 8299, 5999, 7538, 7922, 8699, 5499}
# Adding initial node emission:4112 8700.56 for motif 102
# {7941, 5261, 4111, 4112, 5651, 5399, 5912, 4121, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 9399, 5941, 5945, 7996, 7997, 7230, 5310, 7999, 5699, 5964, 5712, 5331, 5462, 5719, 7392, 7523, 7011, 5734, 4582, 5992, 5994, 8299, 5999, 7538, 7922, 8699, 5499}
# Adding initial node emission:4112 8700.56 for motif 98
# {7941, 5261, 4111, 4112, 5651, 5399, 5912, 4121, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 9399, 5941, 5945, 7996, 7997, 7230, 5310, 7999, 5699, 5964, 5712, 5331, 5462, 5719, 7392, 7523, 7011, 5734, 4582, 5992, 5994, 8299, 5999, 7538, 7922, 8699, 5499}
# Adding initial node emission:4112 8700.56 for motif 38
# {7941, 5261, 4111, 4112, 5651, 5399, 5912, 4121, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 9399, 5941, 5945, 7996, 7997, 7230, 5310, 7999, 5699, 5964, 5712, 5331, 5462, 5719, 7392, 7523, 7011, 5734, 4582, 5992, 5994, 8299, 5999, 7538, 7922, 8699, 5499}
# Adding initial node emission:4112 8700.56 for motif 6
# {7941, 5261, 4111, 4112, 5651, 5399, 5912, 4121, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 9399, 5941, 5945, 7996, 7997, 7230, 5310, 7999, 5699, 5964, 5712, 5331, 5462, 5719, 7392, 7523, 7011, 5734, 4582, 5992, 5994, 8299, 5999, 7538, 7922, 8699, 5499}
# Adding initial node emission:4112 8700.56 for motif 108
# {7941, 5261, 4111, 4112, 5651, 5399, 5912, 4121, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 9399, 5941, 5945, 7996, 7997, 7230, 5310, 7999, 5699, 5964, 5712, 5331, 5462, 5719, 7392, 7523, 7011, 5734, 4582, 5992, 5994, 8299, 5999, 7538, 7922, 8699, 5499}
# Adding initial node emission:4112 8700.56 for motif 14
# {7941, 5261, 4111, 4112, 5651, 5399, 5912, 4121, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 9399, 5941, 5945, 7996, 7997, 7230, 5310, 7999, 5699, 5964, 5712, 5331, 5462, 5719, 7392, 7523, 7011, 5734, 4582, 5992, 5994, 8299, 5999, 7538, 7922, 8699, 5499}
# Adding initial node emission:4112 8700.56 for motif 46
# {7941, 5261, 4111, 4112, 5651, 5399, 5912, 4121, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 9399, 5941, 5945, 7996, 7997, 7230, 5310, 7999, 5699, 5964, 5712, 5331, 5462, 5719, 7392, 7523, 7011, 5734, 4582, 5992, 5994, 8299, 5999, 7538, 7922, 8699, 5499}
# Adding initial node emission:4112 17401.12 for motif 78
# {7941, 5261, 4111, 4112, 5651, 5399, 5912, 4121, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 9399, 5941, 5945, 7996, 7997, 7230, 5310, 7999, 5699, 5964, 5712, 5331, 5462, 5719, 7392, 7523, 7011, 5734, 4582, 5992, 5994, 8299, 5999, 7538, 7922, 8699, 5499}
# Adding initial node emission:4112 8700.56 for motif 238
# {7941, 5261, 4111, 4112, 5651, 5399, 5912, 4121, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 9399, 5941, 5945, 7996, 7997, 7230, 5310, 7999, 5699, 5964, 5712, 5331, 5462, 5719, 7392, 7523, 7011, 5734, 4582, 5992, 5994, 8299, 5999, 7538, 7922, 8699, 5499}
# Adding initial node emission:4511 38222.76 for motif 12
# {7941, 5261, 4111, 4112, 5651, 5399, 5912, 4121, 4511, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 9399, 5941, 5945, 7996, 7997, 7230, 5310, 7999, 5699, 5964, 5712, 5331, 5462, 5719, 7392, 7523, 7011, 5734, 4582, 5992, 5994, 8299, 5999, 7538, 7922, 8699, 5499}
# Adding initial node emission:4511 76445.52 for motif 36
# {7941, 5261, 4111, 4112, 5651, 5399, 5912, 4121, 4511, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 9399, 5941, 5945, 7996, 7997, 7230, 5310, 7999, 5699, 5964, 5712, 5331, 5462, 5719, 7392, 7523, 7011, 5734, 4582, 5992, 5994, 8299, 5999, 7538, 7922, 8699, 5499}
# Adding initial node emission:4511 38222.76 for motif 74
# {7941, 5261, 4111, 4112, 5651, 5399, 5912, 4121, 4511, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 9399, 5941, 5945, 7996, 7997, 7230, 5310, 7999, 5699, 5964, 5712, 5331, 5462, 5719, 7392, 7523, 7011, 5734, 4582, 5992, 5994, 8299, 5999, 7538, 7922, 8699, 5499}
# Adding initial node emission:4511 38222.76 for motif 102
# {7941, 5261, 4111, 4112, 5651, 5399, 5912, 4121, 4511, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 9399, 5941, 5945, 7996, 7997, 7230, 5310, 7999, 5699, 5964, 5712, 5331, 5462, 5719, 7392, 7523, 7011, 5734, 4582, 5992, 5994, 8299, 5999, 7538, 7922, 8699, 5499}
# Adding initial node emission:4511 38222.76 for motif 98
# {7941, 5261, 4111, 4112, 5651, 5399, 5912, 4121, 4511, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 9399, 5941, 5945, 7996, 7997, 7230, 5310, 7999, 5699, 5964, 5712, 5331, 5462, 5719, 7392, 7523, 7011, 5734, 4582, 5992, 5994, 8299, 5999, 7538, 7922, 8699, 5499}
# Adding initial node emission:4511 38222.76 for motif 38
# {7941, 5261, 4111, 4112, 5651, 5399, 5912, 4121, 4511, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 9399, 5941, 5945, 7996, 7997, 7230, 5310, 7999, 5699, 5964, 5712, 5331, 5462, 5719, 7392, 7523, 7011, 5734, 4582, 5992, 5994, 8299, 5999, 7538, 7922, 8699, 5499}
# Adding initial node emission:4511 38222.76 for motif 6
# {7941, 5261, 4111, 4112, 5651, 5399, 5912, 4121, 4511, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 9399, 5941, 5945, 7996, 7997, 7230, 5310, 7999, 5699, 5964, 5712, 5331, 5462, 5719, 7392, 7523, 7011, 5734, 4582, 5992, 5994, 8299, 5999, 7538, 7922, 8699, 5499}
# Adding initial node emission:4511 38222.76 for motif 108
# {7941, 5261, 4111, 4112, 5651, 5399, 5912, 4121, 4511, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 9399, 5941, 5945, 7996, 7997, 7230, 5310, 7999, 5699, 5964, 5712, 5331, 5462, 5719, 7392, 7523, 7011, 5734, 4582, 5992, 5994, 8299, 5999, 7538, 7922, 8699, 5499}
# Adding initial node emission:4511 38222.76 for motif 14
# {7941, 5261, 4111, 4112, 5651, 5399, 5912, 4121, 4511, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 9399, 5941, 5945, 7996, 7997, 7230, 5310, 7999, 5699, 5964, 5712, 5331, 5462, 5719, 7392, 7523, 7011, 5734, 4582, 5992, 5994, 8299, 5999, 7538, 7922, 8699, 5499}
# Adding initial node emission:4511 38222.76 for motif 46
# {7941, 5261, 4111, 4112, 5651, 5399, 5912, 4121, 4511, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 9399, 5941, 5945, 7996, 7997, 7230, 5310, 7999, 5699, 5964, 5712, 5331, 5462, 5719, 7392, 7523, 7011, 5734, 4582, 5992, 5994, 8299, 5999, 7538, 7922, 8699, 5499}
# Adding initial node emission:4511 76445.52 for motif 78
# {7941, 5261, 4111, 4112, 5651, 5399, 5912, 4121, 4511, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 9399, 5941, 5945, 7996, 7997, 7230, 5310, 7999, 5699, 5964, 5712, 5331, 5462, 5719, 7392, 7523, 7011, 5734, 4582, 5992, 5994, 8299, 5999, 7538, 7922, 8699, 5499}
# Adding initial node emission:4511 38222.76 for motif 238
# {7941, 5261, 4111, 4112, 5651, 5399, 5912, 4121, 4511, 6011, 5541, 5422, 5811, 5812, 5813, 5814, 9399, 5941, 5945, 7996, 7997, 7230, 5310, 7999, 5699, 5964, 5712, 5331, 5462, 5719, 7392, 7523, 7011, 5734, 4582, 5992, 5994, 8299, 5999, 7538, 7922, 8699, 5499}
# Motif ID	Total Emission
# 98	7550181.3831
# 36	16317693.2012
# 38	7647632.9781
# 6	10304319.5131
# 102	8928914.6294
# 74	14133699.9885
# 12	12496023.4581
# 108	7732720.6453
# 14	16018365.0011
# 46	7783159.2921
# 78	21424880.5432
# 110	1404739.9426
# 238	8177905.8194
